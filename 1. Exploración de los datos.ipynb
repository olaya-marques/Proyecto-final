# %% [markdown]
# # Exploración de los datos 👩🏼‍💻

# %% [markdown]
# *Antecedentes del tema. Análisis, tratatimiento y exportación de los datos definitivos*

# %% [markdown]
# ## Índice 📎

# %% [markdown]
# 1. Antecedentes del tema
# >- Usos de People Analytics
# >- Attrition en People Analytics
# 2. Estudio
# >- Exportación de librerias
# >- Importación de los datos
# >- Exploración de los datos
# >- Exportación de los datos
# 3. Bibliografía

# %% [markdown]
# ## 1. Antecedentes del tema 📖

# %% [markdown]
# Cada año todas las empresas contratan a nuevos empleados, para lo cual, invierten gran cantidad de tiempo y dinero para la formación y capacitación de los mismos. Además, de la necesidad de mantener el talento (employee engagement) de los ya existentes (aparte de las nuevas incorporaciones); y es en este área dónde Recursos Humanos o de lo que  de aquí en adelante trataremos como **"People Analytics"** toma gran importancia.
#
# Toda clave de éxito empresarial reside en las personas que conforman la empresa es por ello que dedicar parte de los recursos en conocer a la plantilla es una necesidad real. People Analytics se define como un método de investigación basado en datos cuyo objetivo es estudiar las personas que constituyen y forman parte de la entidad, de tal modo que el análisis inteligente de dichos datos extraídos, permita establecer conclusiones fiables y válidas para la toma de decisiones por parte de los altos directivos en relación, a la organización y estructura de la plantilla de su empresa.

# %% [markdown]
# ### 1.1 Usos de People Analytics 👥

# %% [markdown]
# Dentro del departamento de Recursos Humanos, los usos de está nueva tecnología son tan variados como las preguntas que queramos realizar o los aspectos a investigar sobre tales empleados. Un estudio realizado por Deloitte destaca las siguientes 5 funciones:
#
# - **Reclutamiento** : selección del talento mediante la comparación de los currículums anteriores y similares  examinando su progresión laboral del puesto en cuestión dentro de la empresa.
# - **Desarrollo**: establecer el mejor modelo de formación para cada empleado (educación personalizada).
# - **Lealtad**: identificar en tiempo real empleados con signos de desmotivación o intenciones de abandonar la empresa (Attrition).
# - **Compensación**: entender la cantidad e importancia de la remuneración. Construcción de modelos matemáticos que permitan predecir el impacto de las modificaciones salariales.
# - **Organización**: comprensión de las relaciones laborales (independientemente del nivel jerárquico) mediante el análisis del flujo de mensajes, correos u otros medios de comunicación entre el emisor y el receptor.
#
# En definitiva, son muchas las funciones reales aplicables que generan grandes beneficios y ventajas competitivas para la empresa:
#
# - Mejorando la gestión de las personas.
# - Seguimiento y evaluación de eficacia de las decisiones estratétigas tomadas.
# - Identificación de nuevas áreas de mejora.
# - Distribución eficiente de los recursos de la empresa (reduciendo costes de tiempo y dinero).
# - Aumento del bienestar y satisfacción de los empleados y en consecuencia incrementa los índices de productividad.
#
# *📌 De entre todas las funciones o usos de esta tecnológia en esta investigación se tratará en profundidad la lealtad y la retención de talento o employee engagement.*

# %% [markdown]
# ### 1.2 Attrition en People Analytics 🏃🏽

# %% [markdown]
# **"Attrition"**, en español "desgaste" se refiere a la pérdida de empleados a lo largo de un tiempo.
#
# La deserción relativamente alta puede suponer un problema para las empresas: las ofertas de trabajo, los procesos de contratación, el papeleo y la formación de los nuevos empleados suponen grandes costes, que las empresas han de asumir frente a la pérdida de empleados. Además, la continua rotación impide a las organizaciones el crecimiento en conocimientos y experiencia colectiva a largo plazo. Siendo especialmente preocupante en organizaciones o empresas de servicio orientadas al cliente, ya que se prioriza la interacción con personas conocidas y dichas rotaciones pueden generarles falta de confianza y por ende de lealtad.
#
# A pesar de que los profesionales de Recursos Humanos toman medidas y asumen el liderazgo en el diseño de programas de compensación y motivación para la retención de estos, en muchas ocasiones no resulta suficiente.
#
# 📌 Es por ello que mi estudio se basará en el análisis de las variables que más afectan a los empleados y que pueden fomentar está deserción laboral tan común en las organizaciones. A propósito de elaborar un modelo predictivo capaz de analizar las posibilidades y predecir si el empleado o la plantilla en cuestión tiene intenciones o se encuentra en en el umbral de decisión de poder abandonar la entidad.

# %% [markdown]
# ## 2. Estudio 🔎

# %% [markdown]
# Para realizar el análisis comentado se procederá a utilizar la base de datos [IBM HR Analytics Employee Attrition and Performance](https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset) descargada de Kaggle, en la cual se recogen variables como la edad, sueldo, años en la compañía, satisfacción...etc.
# Está base de datos es fictica y fue elaborada por los datascientist de IBM.

# %% [markdown]
# ### 2.1 Exportación de librerias 📚

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2.2 Importación de los datos 📉

# %%
data = pd.read_csv("Data/Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ### 2.3 Exploración de los datos 🕵🏻

# %% [markdown]
# A continuación se procederá al análisis de los datos en relación:
# - Tamaño (cantidad de filas y columnas)
# - Cantidad y tratamiento de NaNs
# - Tipo de datos (catégorico/númerico)
# - Cifras matemáticas de importancia (media, moda, mediana)

# %%
data.shape #tamaño del dataset con el que vamos a trabajar
# Out:
# (1470, 35)

# %%
data.columns #columnas de nuestro dataset(contienen las variables que vamos a trabajar)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# *Trataremos con un dataset conformado por 1470 filas (empleados) y 35 columnas. Antes de analizar las variables (contenidas en cada columna) procederemos a comprobar que nuestro dataset no contiene celdas o valores NaNs. Así como otros análisis previos*

# %%
data.isnull().sum() #comprueba si hay celdas o datos vacíos
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
data. info() #nos muestra información sobre los datos y el tipo de estos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
for column in data.columns:
    print(f"{column}: {data[column].nunique()}") #comprueba los valores únicos
# Out:
# Age: 43
# Attrition: 2
# BusinessTravel: 3
# DailyRate: 886
# Department: 3
# DistanceFromHome: 29
# Education: 5
# EducationField: 6
# EmployeeCount: 1
# EmployeeNumber: 1470
# EnvironmentSatisfaction: 4
# Gender: 2
# HourlyRate: 71
# JobInvolvement: 4
# JobLevel: 5
# JobRole: 9
# JobSatisfaction: 4
# MaritalStatus: 3
# MonthlyIncome: 1349
# MonthlyRate: 1427
# NumCompaniesWorked: 10
# Over18: 1
# OverTime: 2
# PercentSalaryHike: 15
# PerformanceRating: 2
# RelationshipSatisfaction: 4
# StandardHours: 1
# StockOptionLevel: 4
# TotalWorkingYears: 40
# TrainingTimesLastYear: 7
# WorkLifeBalance: 4
# YearsAtCompany: 37
# YearsInCurrentRole: 19
# YearsSinceLastPromotion: 16
# YearsWithCurrManager: 18

# %% [markdown]
# *Observamos que hay columnas como "Over18", "StandardHours", "EmployeeCount" que solo contienen un valor, por ello procederemos al eliminarlas al igual que "EmployeeNumber" ya que disponemos del índice por defecto de pandas para localizar a los empleados y suponen datos inecesarios y repetitivos.*

# %%
data = data.drop(["Over18", "StandardHours", "EmployeeCount","EmployeeNumber"], axis=1) #eliminamos columnas
#data.head()

# %%
data.describe() #principales medidas matemáticas de las variables númericas
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %% [markdown]
# *Con esta información podemos generarnos una idea del perfil de la plantilla que constituye la organización: está empresa en concreto se encuentra con una plantilla de una edad media de 37 años en un rango de min 18 a max 60 años, los cuales trabajan una media de 65 horas semanales, habiendo trabajado y permanecido en la empresa una media de 11 años*.
#
# *Si observamos la relación entre la media y la mediana podemos observar que se encuentran muy dispares entre sí lo que nos lleva a pensar que los datos no están distribuidos regularmente. Destacar la excepción de "DailyRate" cuya media es casi igual que la mediana y la única también cuya varianza resulta relevante/mayor. Dicha anotación también se percibe en el estudio de los máximos y mínimos cuyo valor diferencial también resulta significativo.*

# %% [markdown]
# **A continuación se procederá al estudio de cada columna. Con el objetivo de facilitar más tarde el estudio de la correlación y la importancia de las variables, para el dataset de estudio seleccionado.**
#
# **VARIABLES CATÉGORICAS:**

# %% [markdown]
# - **Attrition (deserción laboral)** 🛑

# %% [markdown]
# *📌 Está será la variable que se intentará predecir*

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["Attrition"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["Attrition"])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# <mark>Existen más posibilidades de que el empleado permanezca en la empresa de que la abandone. **Índice de diserción laboral = 16,1%**.<mark>

# %% [markdown]
# - **Business Travel** ✈️

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["BusinessTravel"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["BusinessTravel"])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# <mark>La mayoría de los empleados realizan viajes tan solo el 10,2% de la compañía no viaja.<mark>

# %%
#emplearemos stripplot de seaborn, permite la visualización de un scatterplot cuando hay una variable categórica

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["BusinessTravel"], data=data)
plt.subplot(1,2,2)
sns.stripplot(y=data["Attrition"], x=data["BusinessTravel"], data=data)
pd.crosstab(data["Attrition"],data["BusinessTravel"])
# Out:
# BusinessTravel  Non-Travel  Travel_Frequently  Travel_Rarely
# Attrition
# No                     138                208            887
# Yes                     12                 69            156

# %% [markdown]
# <p style="color:darkorange;"> Los empleados que realizan más viajes tienden a abandonar más la empresa</p>

# %% [markdown]
# - **Department** 💼

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["Department"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["Department"])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# <mark>De los tres departmentos que hay en la compañía la mayor parte pertenecen a Research y Development despúes de Sales y en última instancia Human Resources<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["Department"], data=data)
plt.subplot(1,2,2)
sns.stripplot(y=data["Attrition"], x=data["Department"], data=data)
pd.crosstab(data["Attrition"],data["Department"])
# Out:
# Department  Human Resources  Research & Development  Sales
# Attrition
# No                       51                     828    354
# Yes                      12                     133     92

# %% [markdown]
# - **Education y EducationField** 👩🏻‍🏫

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["Education"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["Education"])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# <mark>De los 5 rangos medidos de educación siendo el 1 la categoría más baja y 5 la más alta, la mayor parte de los empleados se encuentra en la mediana<mark>
#
# **Entendiéndose tales números como: 1 --> Below College , 2 --> College, 3 --> Bachelor, 4 --> Master, 5 --> Doctor*

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["EducationField"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["EducationField"])
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# <mark> La mayoría de los empleados están especializados en Life Sciences y Medical areas.<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["Education"], data=data)
plt.subplot(1,2,2)
sns.stripplot(y=data["Attrition"], x=data["Education"], data=data)
pd.crosstab(data["Attrition"],data["Education"])
# Out:
# Education    1    2    3    4   5
# Attrition
# No         139  238  473  340  43
# Yes         31   44   99   58   5

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["EducationField"], data=data)
plt.subplot(1,2,2)
sns.stripplot(y=data["Attrition"], x=data["EducationField"], data=data)
pd.crosstab(data["Attrition"],data["EducationField"])
# Out:
# EducationField  Human Resources  Life Sciences  Marketing  Medical  Other  \
# Attrition
# No                           20            517        124      401     71
# Yes                           7             89         35       63     11
#
# EducationField  Technical Degree
# Attrition
# No                           100
# Yes                           32

# %% [markdown]
# <p style="color:darkorange;">En relación, a la Atrrition, parece ser mayor cuanto mayor es el nivel de educación,  en referencia al campo o el area de estudio es Recursos Humanos y otros campos de estudio, coincidiendo con el departamento (Recursos Humanos) que es el que presenta también mayor tasa de abandono.</p>

# %% [markdown]
# - **Enviroment, Job, Relationship  Satisfaction** 😁

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["EnvironmentSatisfaction"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["EnvironmentSatisfaction"])
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %% [markdown]
# <mark>La mayor parte de los empleados se encuentra contentos y conforme con la empresa, sin embargo casi una tercera parte (38,8%) no se encuentran del todo satisfechos (1,2 en el ranking)<mark>
#
# *Entendiendose tales números como: 1-->Low, 2 --> Medium, 3 --> High, 4 --> Very High.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["JobSatisfaction"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["JobSatisfaction"])
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %% [markdown]
# <mark> En general, todos se encuentran satisfechos con sus trabajos, pero alrededor de 569 empleados (de nuevo, la tercera parte aproximadamente) se encuentran insatisfechos.
#
# *Entendiendose tales números como: 1-->Low, 2 --> Medium, 3 --> High, 4 --> Very High.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["RelationshipSatisfaction"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["RelationshipSatisfaction"])
# Out:
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='count'>

# %% [markdown]
# <mark> De nuevo en general se encuentran bastante satisfechos
#
# *Entendiendose tales números como: 1-->Low, 2 --> Medium, 3 --> High, 4 --> Very High.

# %% [markdown]
# <p style="color:darkorange;">Tomamos como hipotésis que cuanto mayor sea el grado de satisfación en cualquier area de los campos anteriores, menor serán las posibilidades de Attrition hacia el empleado.</p>

# %% [markdown]
# - **Gender** 👫🏻

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["Gender"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["Gender"])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# <mark>La mayor parte de los empleados son hombres.<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["Gender"], data=data)
plt.subplot(1,2,2)
sns.stripplot(y=data["Attrition"], x=data["Gender"], data=data)
pd.crosstab(data["Attrition"],data["Gender"])
# Out:
# Gender     Female  Male
# Attrition
# No            501   732
# Yes            87   150

# %% [markdown]
# <p style="color:darkorange;">El género parece influir en la variable Attrition. Comprobémoslo añadiendo otra variable:</p>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="MonthlyIncome",y="Gender",hue="Attrition",data=data)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Gender'>

# %% [markdown]
# <p style="color:darkblue;"> Parece ser que en el caso de las mujeres incluso obteniendo ingresos bajos hay una mayor satisfacción y por ello, menor attrition, siendo tal nula a partir de los 10.000, en cambio los hombres cambian de trabajo incluso despúes de tal cifra.</p>

# %% [markdown]
# - **Job Involvement** 🤩

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["JobInvolvement"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["JobInvolvement"])
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %% [markdown]
# <mark>La mayor parte de los empleados se encuentran involucrados y comprometidos con su trabajo.<mark>
#
# *Entendiendose tales números como: 1-->Low, 2 --> Medium, 3 --> High, 4 --> Very High.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["JobInvolvement"], data=data)
plt.subplot(1,2,2)
sns.stripplot(y=data["Attrition"], x=data["JobInvolvement"], data=data)
pd.crosstab(data["Attrition"],data["JobInvolvement"])
# Out:
# JobInvolvement   1    2    3    4
# Attrition
# No              55  304  743  131
# Yes             28   71  125   13

# %% [markdown]
# <p style="color:darkorange;"> Las posibilidades de Attrition se encuentran cuando el empleado está demasiado envuelto (puede ser por la incapacidad de hacer frente al fracaso o la presión) y poco involucrado (los extremos nunca fueron buenos).</p>

# %% [markdown]
# - **Job Level** 📏

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["JobLevel"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["JobLevel"])
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %% [markdown]
# <mark>Existen 5 tipos de categoría siendo 1 la más baja y 5 la más alta. Es normal, que haya menos posiciones directivas y más posiciones de niveles inferiores, ya que se trata de una empresa; en general es dirigida por pocas personas (toma de decisiones, poder y responsabilidad) hacia un gran número de empleados que constituyen y se encargan de la parte operativa de la misma . Podemos deducir por tanto, que en está empresa hay una distribución de poderes más o menos equitativa, al igual que de nivel de trabajo.<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["JobLevel"], data=data)
plt.subplot(1,2,2)
sns.stripplot(y=data["Attrition"], x=data["JobLevel"], data=data)
pd.crosstab(data["Attrition"],data["JobLevel"])
# Out:
# JobLevel     1    2    3    4   5
# Attrition
# No         400  482  186  101  64
# Yes        143   52   32    5   5

# %% [markdown]
# <p style="color:darkorange;">Empleados en cargos con mayor responsabilidad tienden a abandonar sus puestos de trabajo con mayor frecuencia que aquellos que participan en el proceso más operativo de las actividades llevadas a cabo por la empresa.</p>

# %% [markdown]
# - **Job Role** 👷🏼

# %%
plt.figure(figsize=(25,15))
plt.subplot(2,1,1)
data["JobRole"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(2,1,2)
sns.countplot(x=data["JobRole"])
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %% [markdown]
# <mark>Existen 9 tipos de roles de los cuales los más típicos son Sales Executive y Research Scientists, siendo el menos Human Resources con un 3,5%<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["JobRole"], data=data)
plt.subplot(1,2,2)
sns.stripplot(y=data["Attrition"], x=data["JobRole"], data=data)
pd.crosstab(data["Attrition"],data["JobRole"])
# Out:
# JobRole    Healthcare Representative  Human Resources  Laboratory Technician  \
# Attrition
# No                               122               40                    197
# Yes                                9               12                     62
#
# JobRole    Manager  Manufacturing Director  Research Director  \
# Attrition
# No              97                     135                 78
# Yes              5                      10                  2
#
# JobRole    Research Scientist  Sales Executive  Sales Representative
# Attrition
# No                        245              269                    50
# Yes                        47               57                    33

# %% [markdown]
# <p style="color:darkorange;"> De nuevo se confirma que Recursos Humanos es la más frecuente seguida de los Managers (generalmente puestos que requieren de grandes responsabilidades y cuyo JobLevel es alto).</p>

# %% [markdown]
# - **Marital Status** 💍

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["MaritalStatus"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["MaritalStatus"])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# <mark> Casi todos los empleados están casados. Está variable nos muestra un poco la edad de los empleados que trabajan para esta compañía, debido al alto porcentaje de casados y divorciados podemos predecir que la edad de los empleados será alta. Tal análisis se medirá en profundidad cuando tratemos la variable de edad.<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["MaritalStatus"], data=data)
plt.subplot(1,2,2)
sns.stripplot(y=data["Attrition"], x=data["MaritalStatus"], data=data)
pd.crosstab(data["Attrition"],data["MaritalStatus"])
# Out:
# MaritalStatus  Divorced  Married  Single
# Attrition
# No                  294      589     350
# Yes                  33       84     120

# %% [markdown]
# <p style="color:darkorange;"> Los empleados divorciados muestran mayor tendencia que aquellos que se encuentran casados o solteros.</p>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="MaritalStatus",y="MonthlyIncome",hue="Attrition",data=data)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='MonthlyIncome'>

# %% [markdown]
# <p style="color:darkblue;"> Como se observa en la gráfica en el caso de los solteros, incluso obteniendo remuneraciones altas, tienden a tener una mayor desgaste, cosa que no sucede en los casados o divorciados los cuales a partir de los 125.000 (ingreso) la attrition es nula.</p>

# %% [markdown]
# - **Over Time** ⏱️

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["OverTime"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["OverTime"])
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %% [markdown]
# <mark>Sólo el 28,3% de los empleados de la empresa realizan horas extras.<mark>

# %% [markdown]
# - **Performance Rating** 🙇🏽‍♂️

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["PerformanceRating"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["PerformanceRating"])
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='count'>

# %% [markdown]
# <mark> En lo que se refiere a desempeño/rendimiento, parece ser que no hay ningún empleado que se encuentre en low o good la mayor parte de ellos se encuentra en excellent.<mark>
#
# *Entendiendose tales números como: 1-->Low, 2 --> Good, 3 --> Excellent, 4 --> Outstanding.

# %% [markdown]
# - **Stock Option Level** 💹

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["StockOptionLevel"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["StockOptionLevel"])
# Out:
# <AxesSubplot:xlabel='StockOptionLevel', ylabel='count'>

# %% [markdown]
# <mark> La mayor parte de los empleados no tienen acciones de la empresa, son muy pocos los que invierten en la bolsa de la empresa, además con muy pocas acciones.<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["StockOptionLevel"], data=data)
plt.subplot(1,2,2)
sns.stripplot(y=data["Attrition"], x=data["StockOptionLevel"], data=data)
pd.crosstab(data["Attrition"],data["StockOptionLevel"])
# Out:
# StockOptionLevel    0    1    2   3
# Attrition
# No                477  540  146  70
# Yes               154   56   12  15

# %% [markdown]
# <p style="color:darkorange;"> Empleados con un alto Stock Option Level tienden a una mayor Attrition que aquellos que tienen un bajo nivel.</p>

# %% [markdown]
# - **Training Time (Last Year)** 🏋🏻‍♀️

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["TrainingTimesLastYear"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["TrainingTimesLastYear"])
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='count'>

# %% [markdown]
# <mark>La mayor parte de los empleados tuvieron cursos de formación de 2 a 3 cursos de formación mientras que otros obtuvieron entre 4,5 y 6 y una pequeña parte solo 1 o ninguno.<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["TrainingTimesLastYear"], data=data)
plt.subplot(1,2,2)
sns.stripplot(y=data["Attrition"], x=data["TrainingTimesLastYear"], data=data)
pd.crosstab(data["Attrition"],data["TrainingTimesLastYear"])
# Out:
# TrainingTimesLastYear   0   1    2    3   4    5   6
# Attrition
# No                     39  62  449  422  97  105  59
# Yes                    15   9   98   69  26   14   6

# %% [markdown]
# <p style="color:darkorange;"> Empleados con los niveles más altos y bajos de sesiones de formativas tienden a una mayor Attrition que aquellos que realizaron entre 2 y 3 sesiones.</p>

# %% [markdown]
# - **Work Life Balance** 👨‍👩‍👧‍👧

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data["WorkLifeBalance"].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(x=data["WorkLifeBalance"])
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='count'>

# %% [markdown]
# <mark> El 5,4% de los empleados debe trabajar en ello, mientras que el 10,4% son los únicos que lo alcanzan. Aunque en términos generales la gran parte de empleados tiene el nivel de vida-trabajo equilibrado.<mark>
#
# *Entendiendose tales números como: 1-->Bad, 2 --> Good, 3 --> Better, 4 --> Best.

# %% [markdown]
# **VARIABLES NÚMERICAS**

# %% [markdown]
# - **Age** 👶🏻

# %%
plt.figure(figsize=(10,5))
sns.histplot(data["Age"],kde=True)
plt.axvline(x = data.Age.mean(),c ="red")
print("Maximum",data["Age"].max())
print("Minimum",data["Age"].min())
print("Mean",data["Age"].mean().round(1))
# Out:
# Maximum 60
# Minimum 18
# Mean 36.9

# %% [markdown]
# <mark> La mayor parte de los empleados tiene una edad entre los 28 y 40 años, parece ser que la edad de incorparación más temprana suele rondar entre los 18 años y por el contrario la jubilación se encuentra en torno a los 60 años. En general los datos se encuentran bastante dispersos, la edad media de la compañía es de 36,9 años.<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["Age"], data=data)
plt.subplot(1,2,2)
sns.violinplot(y=data["Attrition"], x=data["Age"], data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Attrition'>

# %% [markdown]
# <p style="color:darkorange;"> A mayor edad menor es el nivel de desgaste de los empleados (a consecuencia de la búsqueda de una mayor estabilidad).</p>

# %%
plt.figure(figsize=(10,10))
sns.catplot(x="JobLevel",y="Age",hue="Attrition",data=data)

# %% [markdown]
# <p style="color:darkblue;"> Partíamos de la base de que a medida que la edad aumenta el JobLevel también se incrementa mientras que disminuye la Attrition. En cambio, se observa que la Attrition es mayor en el nivel 1 y 3 independientemente de la edad.</p>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="Age",y="MonthlyIncome",hue="Attrition",data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='MonthlyIncome'>

# %% [markdown]
# <p style="color:darkblue;"> En este caso, a medida que aumenta la edad, también lo hacen los ingresos mensuales (ello hace que haya menos deserción laboral), sin embargo, si los ingresos son menores en edades más altas aumentan las posibilidades de abandono o deserción laboral.</p>

# %% [markdown]
# - **Distance From Home** 🏡

# %%
plt.figure(figsize=(10,5))
sns.histplot(data["DistanceFromHome"],kde=True)
print("Maximum",data["DistanceFromHome"].max())
print("Minimum",data["DistanceFromHome"].min())
print("Median",data["DistanceFromHome"].median().round(1))
print("Mean",data["DistanceFromHome"].mean().round(1))
# Out:
# Maximum 29
# Minimum 1
# Median 7.0
# Mean 9.2

# %% [markdown]
# <mark>Casi todos los empleados se encuentran a menos de 3km de distancia. Sólo 100 empleados tienen que desplazarse más de 25 kms para llegar a la oficina.<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["DistanceFromHome"], data=data)
plt.subplot(1,2,2)
sns.violinplot(y=data["Attrition"], x=data["DistanceFromHome"], data=data)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Attrition'>

# %% [markdown]
# <p style="color:darkorange;">A medida que aumenta la distancia el desgaste disminuye.</p>

# %% [markdown]
# - **Daily, Hourly y Monthly Rate** 💶

# %%
plt.figure(figsize=(10,5))
sns.histplot(data["DailyRate"],kde=True)
print("Maximum",data["DailyRate"].max())
print("Minimum",data["DailyRate"].min())
# Out:
# Maximum 1499
# Minimum 102

# %% [markdown]
# <mark> Más o menos la tarifa diaria está bastante distribuida.<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(data["HourlyRate"],kde=True)
print("Maximum HR",data["HourlyRate"].max())
print("Minimum HR",data["HourlyRate"].min())
plt.subplot(1,2,2)
sns.histplot(data["MonthlyRate"],kde=True)
print("Maximum MR",data["MonthlyRate"].max())
print("Minimum MR",data["MonthlyRate"].min())
# Out:
# Maximum HR 100
# Minimum HR 30
# Maximum MR 26999
# Minimum MR 2094

# %% [markdown]
# <mark> Los datos de nuevo, se encuentran bastante repartidos y distribuidos mostrando poca varianza entre los mismos.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["DailyRate"], data=data)
plt.subplot(1,2,2)
sns.violinplot(y=data["Attrition"], x=data["DailyRate"], data=data)
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='Attrition'>

# %% [markdown]
# <p style="color:darkorange;">Los empleados muestran una mayor diserción cuanto menor es la tasa diaria.</p>

# %% [markdown]
# - **Monthly Income** 💰

# %%
plt.figure(figsize=(10,5))
sns.histplot(data["MonthlyIncome"],kde=True)
plt.axvline(x = data.MonthlyIncome.median(),c ="green")
print("Maximum",data["MonthlyIncome"].max())
print("Minimum",data["MonthlyIncome"].min())
print("Median",data["MonthlyIncome"].median().round(1))
# Out:
# Maximum 19999
# Minimum 1009
# Median 4919.0

# %% [markdown]
# <mark>Los empleados obtienen una remuneración entre 1009 y 19999 euros (cantidades muy dispares entre sí). La mayoria de los empleados gana alrededor de los 2500. Mientras que menos de 50 empleados obtienten los ingresos más altos.<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["MonthlyIncome"], data=data)
plt.subplot(1,2,2)
sns.violinplot(y=data["Attrition"], x=data["MonthlyIncome"], data=data)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Attrition'>

# %% [markdown]
# <p style="color:darkorange;">Cuanto menor es mayor es la tasa de deserción y viceversa.</p>

# %% [markdown]
# - **Percent Salary Hike** ⏫

# %%
plt.figure(figsize=(10,5))
sns.histplot(data["PercentSalaryHike"],kde=True)
plt.axvline(x = data.PercentSalaryHike.mean(),c ="red")
plt.axvline(x = data.PercentSalaryHike.median(),c ="green")
print("Maximum",data["PercentSalaryHike"].max())
print("Minimum",data["PercentSalaryHike"].min())
# Out:
# Maximum 25
# Minimum 11

# %% [markdown]
# <mark> Casi todos los empleados tienen una subida de salario de entre el 11 y el 15% muy pocos obtienen el grado más alto de 24 y 25%.<mark>

# %% [markdown]
# - **Total Working Years y  Years At Company** 🗓️

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(data["TotalWorkingYears"],kde=True)
print("Maximum TW",data["TotalWorkingYears"].max())
plt.subplot(1,2,2)
sns.histplot(data["YearsAtCompany"],kde=True)
print("Maximum Y",data["YearsAtCompany"].max())
# Out:
# Maximum TW 40
# Maximum Y 40

# %% [markdown]
# <mark> Por lo general, los empleados trabajan en la compañia por un periodod de entre 5 y 11 años. Observamos que son muy pocos los empleados que alcanzan los 30 años en la compañía, la mayoría de ellos solo permanece un año, en cualquier caso, los datos se encuentran muy sesgados con una clara asimetría hacia la derecha.<mark>

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(hue=data["Attrition"], x=data["YearsAtCompany"], data=data)
plt.subplot(1,2,2)
sns.violinplot(y=data["Attrition"], x=data["YearsAtCompany"], data=data)
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Attrition'>

# %% [markdown]
# <p style="color:darkorange;"> Observamos que existe una alta diserción laboral cuando se trata de los primeros años (por lo general, los nuevos empleados tienden a cambiar con más facilidad por que les surgen opciones con mejores salarios o salidas profesionales). A partir de los 5 años es más baja.</p>

# %%
plt.figure(figsize=(20,20))
sns.catplot(x="Age",y="YearsAtCompany",hue="Attrition",data=data)

# %% [markdown]
# <p style="color:darkblue;"> A medida que aumenta la edad y los años en la empresa las personas tienden a abandonar la entidad, siendo tal posibilidad mayor en las edades más altas con menos años en las empresas.</p>

# %% [markdown]
# <mark>**RESUMEN**<mark>

# %% [markdown]
# - A menor JobLevel, MonthlyIncome, YearAtCompany y TotalWorkingYears las posibilidades de attrition aumentan.
# - A más viajes (BusinessTravel) mayor posibilidad de deserción laboral.
# - Es más probable que se mantenga fiel (menor attrition) aquellos empleados que pertenezcan al departamento de Investigación y Desarrollo.
# - Los trabajadores dedicados o con títulos en el area de Recursos Humanos tienden más a abandonar su puesto de trabajo.
# - Los hombres tienden más a rotar de trabajo.
# - Los trabajadores de Técnico de laboratorio, Representante de ventas y Recursos humanos tienen más probabilidades de renunciar que los que se encuentran en otras posiciones/roles.
# - Los solteros presentan más posibilidades de attrition que aquellos que se encuentran divorciados o casados.
# - Hay una mayor probabilidad de que aquellos trabajadores que trabajan horas extras o más horas (OverTime) renuncien con respecto a los demás.

# %% [markdown]
# **Una vez estudiados las relaciones y los datos proporcionados por cada columna procederemos al estudio de sus correlaciones para más tarde la elaboración del modelo predictivo, cuya variable a intuir será la attrition.**

# %%
plt.figure(figsize=(25,25))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <mark>**ANÁLISIS DE CORRELACIÓN**<mark>
#
# Variables correlacionadas:
# - MonthlyIncome & JobLevel
# - JobLevel & WorkingHours
# - WorkingHours & JobLevel
# - Age & TotalWorkingYears (positive)
# - MaritalStatus & StockOptionLevel (negative)

# %% [markdown]
# ### 2.4 Exportación de los datos 🚀

# %%
data.to_csv("Data/Attrition_modeldata.csv")

# %% [markdown]
# ## Bibliografía 🖇️

# %% [markdown]
# - [People Analytics: que és y por dónde empezar](http://www.rrhhdigital.com/secciones/tecnologia-e-innovacion/145811/People-Analytics-que-es-y-por-donde-empezar?target=_self)
# - [People Analytics: ¿Qué es? Guía paso a paso y ejemplos](https://www.felicidadeneltrabajo.es/ideas-para-empresarios/hr-people-analytics-que-es-guia-ejemplos/)
# - [People Analytics Data Integrations: the good, the bad and the Ugly](https://www.onemodel.co/blog/people-analytics-data-integrations)
# - [7HR Data Sets for People Analytics](https://www.aihr.com/blog/hr-data-sets-people-analytics/)
# - [People Analytics | Como medir el talento con datos](https://www.bizneo.com/blog/people-analytics-medir-el-talento-con-datos/)
# - [Casos Reales de implantación de People Analytics y cómo impulsarlo](https://www.equiposytalento.com/talentstreet/noticias/2020/05/15/casos-reales-de-implantacion-de-people-analytics-y-como-impulsarlo/4056/)
# - [People Analytics](https://www.coursera.org/learn/wharton-people-analytics#syllabus)
